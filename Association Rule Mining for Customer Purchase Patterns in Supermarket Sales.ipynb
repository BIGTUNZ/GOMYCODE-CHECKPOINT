# %% [markdown]
# ### Instal Libraries

# %%
pip install mlxtend pandas plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Running the Apriori Algorithm on the Toy Dataset

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

toy_dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],
               ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],
               ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],
               ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],
               ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# Encoding the dataset
te = TransactionEncoder()
te_ary = te.fit(toy_dataset).transform(toy_dataset)
toy_df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# Apply apriori algorithm
frequent_itemsets = apriori(toy_df, min_support=0.1, use_colnames=True)

# Display results
frequent_itemsets
# Out:
#      support                                        itemsets
# 0        0.4                                         (Dress)
# 1        0.4                                      (Earrings)
# 2        0.6                                           (Hat)
# 3        0.4                                         (Heels)
# 4        0.2                                      (Necklace)
# ..       ...                                             ...
# 146      0.2         (Heels, Scarf, Earrings, Necklace, Hat)
# 147      0.2          (Scarf, Skirt, Earrings, Pants, Shirt)
# 148      0.2            (Scarf, Skirt, Pants, Hat, Sneakers)
# 149      0.2       (Skirt, Pants, Sunglasses, Hat, Sneakers)
# 150      0.2  (Heels, Scarf, Earrings, Necklace, Dress, Hat)
#
# [151 rows x 2 columns]

# %%
# Generate association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
rules
# Out:
#            antecedents                           consequents  \
# 0              (Dress)                               (Heels)
# 1              (Heels)                               (Dress)
# 2           (Necklace)                               (Dress)
# 3            (Sandals)                               (Dress)
# 4              (Dress)                               (Scarf)
# ..                 ...                                   ...
# 691    (Hat, Earrings)       (Dress, Heels, Scarf, Necklace)
# 692  (Dress, Necklace)         (Hat, Heels, Scarf, Earrings)
# 693    (Hat, Necklace)       (Dress, Heels, Scarf, Earrings)
# 694       (Dress, Hat)    (Heels, Scarf, Earrings, Necklace)
# 695         (Necklace)  (Heels, Scarf, Earrings, Dress, Hat)
#
#      antecedent support  consequent support  support  confidence  lift  \
# 0                   0.4                 0.4      0.4         1.0  2.50
# 1                   0.4                 0.4      0.4         1.0  2.50
# ...

# %%
# Open the groceries.csv file in read mode ('r')
with open("Market_Basket_Optimisation.csv", 'r') as file:
    
# Read the file line by line, strip any leading/trailing whitespace, 
# and split each line by commas to create a list of items (i.e., a transaction)
    data = [line.strip().split(',') for line in file]

# Display the first five transactions (each transaction is a list of items)
for transaction in data[:5]:
    print(transaction)
# Out:
# ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil']
# ['burgers', 'meatballs', 'eggs']
# ['chutney']
# ['turkey', 'avocado']
# ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea']

# %%
# Create a one-hot encoded DataFrame for the items
te = TransactionEncoder()
te_ary = te.fit(data).transform(data)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
# Apply apriori algorithm
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)

# Display results
frequent_itemsets
# Out:
#       support                                 itemsets
# 0    0.020397                                (almonds)
# 1    0.033329                                (avocado)
# 2    0.010799                         (barbecue sauce)
# 3    0.014265                              (black tea)
# 4    0.011465                             (body spray)
# ..        ...                                      ...
# 252  0.011065       (milk, ground beef, mineral water)
# 253  0.017064  (ground beef, spaghetti, mineral water)
# 254  0.015731         (milk, spaghetti, mineral water)
# 255  0.010265    (olive oil, spaghetti, mineral water)
# 256  0.011465     (pancakes, spaghetti, mineral water)
#
# [257 rows x 2 columns]

# %%
# Use the frequent itemsets to generate association rules.
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Display the first few association rules
rules.head()
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0        (avocado)  (mineral water)            0.033329            0.238368
# 1  (mineral water)        (avocado)            0.238368            0.033329
# 2        (burgers)           (cake)            0.087188            0.081056
# 3           (cake)        (burgers)            0.081056            0.087188
# 4        (burgers)      (chocolate)            0.087188            0.163845
#
#     support  confidence      lift  leverage  conviction  zhangs_metric
# 0  0.011598    0.348000  1.459926  0.003654    1.168147       0.325896
# 1  0.011598    0.048658  1.459926  0.003654    1.016113       0.413630
# 2  0.011465    0.131498  1.622319  0.004398    1.058080       0.420238
# 3  0.011465    0.141447  1.622319  0.004398    1.063198       0.417434
# 4  0.017064    0.195719  1.194537  0.002779    1.039630       0.178411

# %%
# Filter the rules to focus on those with high confidence or lift values.
strong_rules = rules[(rules['lift'] > 1) & (rules['confidence'] > 0.5)]

# Sort the rules by lift, in descending order
strong_rules = strong_rules.sort_values(by='lift', ascending=False)

# Display the filtered rules
strong_rules
# Out:
#              antecedents      consequents  antecedent support  \
# 342  (eggs, ground beef)  (mineral water)            0.019997
# 376  (milk, ground beef)  (mineral water)            0.021997
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 342            0.238368  0.010132    0.506667  2.125563  0.005365    1.543848
# 376            0.238368  0.011065    0.503030  2.110308  0.005822    1.532552
#
#      zhangs_metric
# 342       0.540342
# 376       0.537969

# %% [markdown]
# ## Suggested Business Plan Based on Findings
#
# Loyalty Program Targeting:
# Target loyalty program members who frequently buy milk, eggs, or ground beef with special offers or points when they buy mineral water, as this may increase their tendency to buy these products together.
#
# Inventory and Stocking Strategies:
# Given the higher likelihood of mineral water being purchased with these items, ensure sufficient stock levels for mineral water, especially if promotions or cross-promotions are running.
#
# These strategies could help the supermarket improve sales of mineral water by leveraging its association with popular items like milk, eggs, and ground beef.
